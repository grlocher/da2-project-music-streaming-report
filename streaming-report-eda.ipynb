# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df1 = pd.read_csv('genres_v2.csv')
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42305 entries, 0 to 42304
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      42305 non-null  float64
#  1   energy            42305 non-null  float64
#  2   key               42305 non-null  int64
#  3   loudness          42305 non-null  float64
#  4   mode              42305 non-null  int64
#  5   speechiness       42305 non-null  float64
#  6   acousticness      42305 non-null  float64
#  7   instrumentalness  42305 non-null  float64
#  8   liveness          42305 non-null  float64
#  9   valence           42305 non-null  float64
#  10  tempo             42305 non-null  float64
#  11  type              42305 non-null  object
#  12  id                42305 non-null  object
#  13  uri               42305 non-null  object
#  14  track_href        42305 non-null  object
#  15  analysis_url      42305 non-null  object
#  16  duration_ms       42305 non-null  int64
#  17  time_signature    42305 non-null  int64
#  18  genre             42305 non-null  object
#  19  song_name         21519 non-null  object
#  20  Unnamed: 0        20780 non-null  float64
#  21  title             20780 non-null  object
# dtypes: float64(10), int64(4), object(8)
# memory usage: 7.1+ MB
# /var/folders/h_/q1_b1v7x1p3dp6dhckks0t180000gn/T/ipykernel_9699/4028231336.py:1: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df1 = pd.read_csv('genres_v2.csv')

# %%
df1.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
# 3          0.000000    0.1140   0.1750  ...  0VSXnJqQkwuH2ei1nOQ1nu
# 4          0.000000    0.1660   0.5910  ...  4jCeguq9rMTlbMmPHuO7S3
#
#                                     uri  \
# 0  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# 1  spotify:track:7pgJBLVz5VmnL7uGHmRj6p
# 2  spotify:track:0vSWgAlfpye0WCGeNmuNhy
# 3  spotify:track:0VSXnJqQkwuH2ei1nOQ1nu
# 4  spotify:track:4jCeguq9rMTlbMmPHuO7S3
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...
# 1  https://api.spotify.com/v1/tracks/7pgJBLVz5Vmn...
# 2  https://api.spotify.com/v1/tracks/0vSWgAlfpye0...
# 3  https://api.spotify.com/v1/tracks/0VSXnJqQkwuH...
# 4  https://api.spotify.com/v1/tracks/4jCeguq9rMTl...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Vc6...      124539
# 1  https://api.spotify.com/v1/audio-analysis/7pgJ...      224427
# 2  https://api.spotify.com/v1/audio-analysis/0vSW...       98821
# 3  https://api.spotify.com/v1/audio-analysis/0VSX...      123661
# 4  https://api.spotify.com/v1/audio-analysis/4jCe...      123298
#
#   time_signature      genre                                      song_name  \
# 0              4  Dark Trap                            Mercury: Retrograde
# 1              4  Dark Trap                                      Pathology
# 2              4  Dark Trap                                       Symbiote
# 3              3  Dark Trap  ProductOfDrugs (Prod. The Virus and Antidote)
# 4              4  Dark Trap                                          Venom
#
#   Unnamed: 0 title
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN
#
# [5 rows x 22 columns]

# %%
df2 = pd.read_csv('playlists.csv')
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39 entries, 0 to 38
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Playlist  39 non-null     object
#  1   Genre     39 non-null     object
# dtypes: object(2)
# memory usage: 756.0+ bytes

# %%
df2.head()
# Out:
#                  Playlist      Genre
# 0  19WuHd4MxWLzE1fpMmw4S4  Dark Trap
# 1  6XyR8uzgkSoDzHuOxxRtLH  Dark Trap
# 2  37Ij3ofyhvEhFEH8YZMZ2X  Dark Trap
# 3  07zTlfPpsxeoWdumbkNWMI  Dark Trap
# 4  2dClSRLsnptdkDQnpi5H2f  Dark Trap

# %% [markdown]
# #### checking for missing vaues and dropping or filling in rows

# %%
print(df1.isnull().sum())
# Out:
# danceability            0
# energy                  0
# key                     0
# loudness                0
# mode                    0
# speechiness             0
# acousticness            0
# instrumentalness        0
# liveness                0
# valence                 0
# tempo                   0
# type                    0
# id                      0
# uri                     0
# track_href              0
# analysis_url            0
# duration_ms             0
# time_signature          0
# genre                   0
# song_name           20786
# Unnamed: 0          21525
# title               21525
# dtype: int64

# %%
print(df2.isnull().sum())
# Out:
# Playlist    0
# Genre       0
# dtype: int64

# %%
df1.drop(columns=['Unnamed: 0', 'title'], inplace=True)

# %%
print(df1.isnull().sum())
# Out:
# danceability            0
# energy                  0
# key                     0
# loudness                0
# mode                    0
# speechiness             0
# acousticness            0
# instrumentalness        0
# liveness                0
# valence                 0
# tempo                   0
# type                    0
# id                      0
# uri                     0
# track_href              0
# analysis_url            0
# duration_ms             0
# time_signature          0
# genre                   0
# song_name           20786
# dtype: int64

# %% [markdown]
# ##### Replacing song_name nulls with 'unknown'

# %%
df1['song_name'].fillna('Unknown', inplace=True)

# %% [markdown]
# ##### Checking types

# %%
print(df1.dtypes)
print(df2.dtypes)
# Out:
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms           int64
# time_signature        int64
# genre                object
# song_name            object
# dtype: object
# Playlist    object
# Genre       object
# dtype: object

# %% [markdown]
# #### Looking for duplicates

# %%
duplicates = df1[df1.duplicated()]
print(duplicates)
print(f"Number of duplicate rows: {duplicates.shape[0]}")
# Out:
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 21587         0.845   0.938    9    -5.891     0       0.0502      0.003060
# 21725         0.721   0.743    6    -9.638     1       0.0534      0.002770
# 21726         0.784   0.924    0    -7.488     0       0.0475      0.008260
# 21736         0.851   0.866    6    -5.078     1       0.0532      0.003560
# 21771         0.779   0.937    9    -6.269     0       0.0496      0.044300
# ...             ...     ...  ...       ...   ...          ...           ...
# 42290         0.367   0.872    7    -5.362     0       0.0485      0.005670
# 42293         0.255   0.848   11    -3.306     0       0.0360      0.000665
# 42296         0.512   0.891    9    -3.203     0       0.4100      0.020500
# 42299         0.423   0.904    4    -1.865     0       0.0615      0.010300
# 42301         0.517   0.768    0    -7.922     0       0.0479      0.022500
#
#        instrumentalness  liveness  valence    tempo            type  \
# 21587          0.855000    0.0896   0.7550  127.007  audio_features
# 21725          0.753000    0.0916   0.5970  128.005  audio_features
# 21726          0.020500    0.0686   0.8030  123.988  audio_features
# 21736          0.415000    0.1110   0.6090  125.994  audio_features
# 21771          0.101000    0.0912   0.4900  125.025  audio_features
# ...                 ...       ...      ...      ...             ...
# 42290          0.000000    0.8250   0.1830  155.066  audio_features
# 42293          0.000019    0.3430   0.1730  152.840  audio_features
# 42296          0.000000    0.3310   0.0804  155.036  audio_features
# 42299          0.000000    0.1710   0.1780  150.046  audio_features
# 42301          0.000018    0.2050   0.3830  149.928  audio_features
#
#                            id                                   uri  \
# 21587  7n0cOjwadpms08yfGEeyOQ  spotify:track:7n0cOjwadpms08yfGEeyOQ
# 21725  0cHwnuKBeZsDuhGRc99tHu  spotify:track:0cHwnuKBeZsDuhGRc99tHu
# 21726  0U65qiH70mcfB1wyF0Mal0  spotify:track:0U65qiH70mcfB1wyF0Mal0
# 21736  5oXkfuwL7HieiHzvmWsaGo  spotify:track:5oXkfuwL7HieiHzvmWsaGo
# 21771  3T00mhdOYUuM5yiuPs3xhs  spotify:track:3T00mhdOYUuM5yiuPs3xhs
# ...                       ...                                   ...
# 42290  5hhefTdz9pJM5HfP3uqVJ3  spotify:track:5hhefTdz9pJM5HfP3uqVJ3
# 42293  1V02rC4Ho6n87kUCF5aRbB  spotify:track:1V02rC4Ho6n87kUCF5aRbB
# 42296  3VmOfQzdx9WB7PNxaBhIPc  spotify:track:3VmOfQzdx9WB7PNxaBhIPc
# 42299  7KdYf9e61IxyuWZBW5OFvw  spotify:track:7KdYf9e61IxyuWZBW5OFvw
# 42301  0he2ViGMUO3ajKTxLOfWVT  spotify:track:0he2ViGMUO3ajKTxLOfWVT
#
#                                               track_href  \
# 21587  https://api.spotify.com/v1/tracks/7n0cOjwadpms...
# 21725  https://api.spotify.com/v1/tracks/0cHwnuKBeZsD...
# 21726  https://api.spotify.com/v1/tracks/0U65qiH70mcf...
# 21736  https://api.spotify.com/v1/tracks/5oXkfuwL7Hie...
# 21771  https://api.spotify.com/v1/tracks/3T00mhdOYUuM...
# ...                                                  ...
# 42290  https://api.spotify.com/v1/tracks/5hhefTdz9pJM...
# 42293  https://api.spotify.com/v1/tracks/1V02rC4Ho6n8...
# 42296  https://api.spotify.com/v1/tracks/3VmOfQzdx9WB...
# 42299  https://api.spotify.com/v1/tracks/7KdYf9e61Ixy...
# 42301  https://api.spotify.com/v1/tracks/0he2ViGMUO3a...
#
#                                             analysis_url  duration_ms  \
# 21587  https://api.spotify.com/v1/audio-analysis/7n0c...       371811
# 21725  https://api.spotify.com/v1/audio-analysis/0cHw...       270000
# 21726  https://api.spotify.com/v1/audio-analysis/0U65...       238027
# 21736  https://api.spotify.com/v1/audio-analysis/5oXk...       188089
# 21771  https://api.spotify.com/v1/audio-analysis/3T00...       185000
# ...                                                  ...          ...
# 42290  https://api.spotify.com/v1/audio-analysis/5hhe...       226859
# 42293  https://api.spotify.com/v1/audio-analysis/1V02...       169804
# 42296  https://api.spotify.com/v1/audio-analysis/3VmO...       213290
# 42299  https://api.spotify.com/v1/audio-analysis/7KdY...       264800
# 42301  https://api.spotify.com/v1/audio-analysis/0he2...       210112
#
#        time_signature      genre song_name
# 21587               4  techhouse   Unknown
# 21725               4  techhouse   Unknown
# 21726               4  techhouse   Unknown
# 21736               4  techhouse   Unknown
# 21771               4  techhouse   Unknown
# ...               ...        ...       ...
# 42290               4  hardstyle   Unknown
# 42293               4  hardstyle   Unknown
# 42296               4  hardstyle   Unknown
# 42299               4  hardstyle   Unknown
# 42301               4  hardstyle   Unknown
#
# [3218 rows x 20 columns]
# Number of duplicate rows: 3218

# %% [markdown]
# #### Standardize Column Names

# %%
df1.columns = df1.columns.str.strip().str.lower().str.replace(' ', '_')
df2.columns = df2.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
print(df1.columns)
print(df2.columns)
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'id', 'uri', 'track_href', 'analysis_url', 'duration_ms',
#        'time_signature', 'genre', 'song_name'],
#       dtype='object')
# Index(['playlist', 'genre'], dtype='object')

# %% [markdown]
# #### Merge datasets on genre

# %%
merged_df = pd.merge(df1, df2, left_on='genre', right_on='genre', how='inner')

# %%
print(merged_df.head())
print(f"Shape of merged DataFrame: {merged_df.shape}")
print(merged_df.describe(include='all'))
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1         0.42        0.0598
# 1         0.831   0.814    2    -7.364     1         0.42        0.0598
# 2         0.831   0.814    2    -7.364     1         0.42        0.0598
# 3         0.831   0.814    2    -7.364     1         0.42        0.0598
# 4         0.831   0.814    2    -7.364     1         0.42        0.0598
#
#    instrumentalness  liveness  valence  ...            type  \
# 0            0.0134    0.0556    0.389  ...  audio_features
# 1            0.0134    0.0556    0.389  ...  audio_features
# 2            0.0134    0.0556    0.389  ...  audio_features
# 3            0.0134    0.0556    0.389  ...  audio_features
# 4            0.0134    0.0556    0.389  ...  audio_features
#
#                        id                                   uri  \
# 0  2Vc6NJ9PW9gD9q343XFRKx  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# 1  2Vc6NJ9PW9gD9q343XFRKx  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# 2  2Vc6NJ9PW9gD9q343XFRKx  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# 3  2Vc6NJ9PW9gD9q343XFRKx  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# 4  2Vc6NJ9PW9gD9q343XFRKx  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...
# 1  https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...
# 2  https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...
# 3  https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...
# 4  https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Vc6...      124539
# 1  https://api.spotify.com/v1/audio-analysis/2Vc6...      124539
# 2  https://api.spotify.com/v1/audio-analysis/2Vc6...      124539
# 3  https://api.spotify.com/v1/audio-analysis/2Vc6...      124539
# 4  https://api.spotify.com/v1/audio-analysis/2Vc6...      124539
#
#    time_signature      genre            song_name                playlist
# 0               4  Dark Trap  Mercury: Retrograde  19WuHd4MxWLzE1fpMmw4S4
# 1               4  Dark Trap  Mercury: Retrograde  6XyR8uzgkSoDzHuOxxRtLH
# 2               4  Dark Trap  Mercury: Retrograde  37Ij3ofyhvEhFEH8YZMZ2X
# 3               4  Dark Trap  Mercury: Retrograde  07zTlfPpsxeoWdumbkNWMI
# 4               4  Dark Trap  Mercury: Retrograde  2dClSRLsnptdkDQnpi5H2f
#
# [5 rows x 21 columns]
# Shape of merged DataFrame: (93876, 21)
#         danceability        energy           key      loudness          mode  \
# count   93876.000000  93876.000000  93876.000000  93876.000000  93876.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.640232      0.672124      5.135285     -6.816974      0.588979
# std         0.164815      0.187146      3.658011      2.966376      0.492022
# min         0.065100      0.000243      0.000000    -33.357000      0.000000
# 25%         0.524000      0.541000      1.000000     -8.435000      0.000000
# 50%         0.654000      0.680000      5.000000     -6.405000      1.000000
# 75%         0.768000      0.824000      8.000000     -4.766000      1.000000
# max         0.988000      0.999000     11.000000      3.148000      1.000000
#
#          speechiness  acousticness  instrumentalness      liveness  \
# count   93876.000000  93876.000000      93876.000000  93876.000000
# unique           NaN           NaN               NaN           NaN
# top              NaN           NaN               NaN           NaN
# freq             NaN           NaN               NaN           NaN
# mean        0.158851      0.167220          0.083819      0.198505
# std         0.135390      0.219114          0.231762      0.153884
# min         0.022700      0.000001          0.000000      0.021000
# 25%         0.049900      0.011800          0.000000      0.101000
# 50%         0.104000      0.069800          0.000002      0.132000
# 75%         0.246000      0.237000          0.001050      0.258000
# max         0.946000      0.988000          0.989000      0.973000
#
#              valence  ...            type                      id  \
# count   93876.000000  ...           93876                   93876
# unique           NaN  ...               1                   18358
# top              NaN  ...  audio_features  7GX5flRQZVHRAGd6B4TmDO
# freq             NaN  ...           93876                      23
# mean        0.410168  ...             NaN                     NaN
# std         0.233549  ...             NaN                     NaN
# min         0.020600  ...             NaN                     NaN
# 25%         0.214000  ...             NaN                     NaN
# 50%         0.392000  ...             NaN                     NaN
# 75%         0.585000  ...             NaN                     NaN
# max         0.980000  ...             NaN                     NaN
#
#                                          uri  \
# count                                  93876
# unique                                 18358
# top     spotify:track:7GX5flRQZVHRAGd6B4TmDO
# freq                                      23
# mean                                     NaN
# std                                      NaN
# min                                      NaN
# 25%                                      NaN
# 50%                                      NaN
# 75%                                      NaN
# max                                      NaN
#
#                                                track_href  \
# count                                               93876
# unique                                              18358
# top     https://api.spotify.com/v1/tracks/7GX5flRQZVHR...
# freq                                                   23
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#                                              analysis_url    duration_ms  \
# count                                               93876   93876.000000
# unique                                              18358            NaN
# top     https://api.spotify.com/v1/audio-analysis/7GX5...            NaN
# freq                                                   23            NaN
# mean                                                  NaN  199689.078977
# std                                                   NaN   60565.124169
# min                                                   NaN   38333.000000
# 25%                                                   NaN  156223.500000
# 50%                                                   NaN  199173.000000
# 75%                                                   NaN  236093.000000
# max                                                   NaN  728413.000000
#
#         time_signature      genre song_name                playlist
# count     93876.000000      93876     93876                   93876
# unique             NaN          8     15435                      39
# top                NaN  Dark Trap   Forever  3CCC01CIQgca5cu14tgszj
# freq               NaN      22890        82                    5875
# mean          3.961620        NaN       NaN                     NaN
# std           0.339573        NaN       NaN                     NaN
# min           1.000000        NaN       NaN                     NaN
# 25%           4.000000        NaN       NaN                     NaN
# 50%           4.000000        NaN       NaN                     NaN
# 75%           4.000000        NaN       NaN                     NaN
# max           5.000000        NaN       NaN                     NaN
#
# [11 rows x 21 columns]

# %%
merged_df.isnull().sum()
# Out:
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# id                  0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# genre               0
# song_name           0
# playlist            0
# dtype: int64

# %%
merged_df.dtypes
# Out:
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# type                 object
# id                   object
# uri                  object
# track_href           object
# analysis_url         object
# duration_ms           int64
# time_signature        int64
# genre                object
# song_name            object
# playlist             object
# dtype: object

# %%
merged_df.describe()
# Out:
#        danceability        energy           key      loudness          mode  \
# count  93876.000000  93876.000000  93876.000000  93876.000000  93876.000000
# mean       0.640232      0.672124      5.135285     -6.816974      0.588979
# std        0.164815      0.187146      3.658011      2.966376      0.492022
# min        0.065100      0.000243      0.000000    -33.357000      0.000000
# 25%        0.524000      0.541000      1.000000     -8.435000      0.000000
# 50%        0.654000      0.680000      5.000000     -6.405000      1.000000
# 75%        0.768000      0.824000      8.000000     -4.766000      1.000000
# max        0.988000      0.999000     11.000000      3.148000      1.000000
#
#         speechiness  acousticness  instrumentalness      liveness  \
# count  93876.000000  93876.000000      93876.000000  93876.000000
# mean       0.158851      0.167220          0.083819      0.198505
# std        0.135390      0.219114          0.231762      0.153884
# min        0.022700      0.000001          0.000000      0.021000
# 25%        0.049900      0.011800          0.000000      0.101000
# 50%        0.104000      0.069800          0.000002      0.132000
# 75%        0.246000      0.237000          0.001050      0.258000
# max        0.946000      0.988000          0.989000      0.973000
#
#             valence         tempo    duration_ms  time_signature
# count  93876.000000  93876.000000   93876.000000    93876.000000
# mean       0.410168    152.442228  199689.078977        3.961620
# std        0.233549     29.079427   60565.124169        0.339573
# min        0.020600     57.967000   38333.000000        1.000000
# 25%        0.214000    129.985000  156223.500000        4.000000
# 50%        0.392000    149.975000  199173.000000        4.000000
# 75%        0.585000    175.330000  236093.000000        4.000000
# max        0.980000    220.290000  728413.000000        5.000000

# %%
numerical_df = merged_df.select_dtypes(include=['float64', 'int64'])
correlation_matrix = numerical_df.corr()
print(correlation_matrix)
# Out:
#                   danceability    energy       key  loudness      mode  \
# danceability          1.000000 -0.209545 -0.005418 -0.074167  0.009820
# energy               -0.209545  1.000000  0.016262  0.711265  0.035032
# key                  -0.005418  0.016262  1.000000 -0.003850 -0.211680
# loudness             -0.074167  0.711265 -0.003850  1.000000  0.061363
# mode                  0.009820  0.035032 -0.211680  0.061363  1.000000
# speechiness           0.196718  0.062653  0.003386  0.016599  0.003057
# acousticness         -0.019075 -0.482647  0.025720 -0.365350 -0.050529
# instrumentalness     -0.173129 -0.030661  0.033262 -0.236158 -0.056438
# liveness             -0.110047  0.226831  0.007558  0.145870  0.041885
# valence               0.314255  0.240285  0.052988  0.231627 -0.001438
# tempo                -0.083156  0.045193  0.002969  0.035191 -0.011169
# duration_ms          -0.143710  0.000305  0.031914  0.008273 -0.084726
# time_signature        0.101835  0.066915  0.010861  0.056346 -0.005605
#
#                   speechiness  acousticness  instrumentalness  liveness  \
# danceability         0.196718     -0.019075         -0.173129 -0.110047
# energy               0.062653     -0.482647         -0.030661  0.226831
# key                  0.003386      0.025720          0.033262  0.007558
# loudness             0.016599     -0.365350         -0.236158  0.145870
# mode                 0.003057     -0.050529         -0.056438  0.041885
# speechiness          1.000000      0.009826         -0.218300  0.118979
# acousticness         0.009826      1.000000         -0.014298 -0.115431
# instrumentalness    -0.218300     -0.014298          1.000000 -0.036005
# liveness             0.118979     -0.115431         -0.036005  1.000000
# valence              0.198325     -0.052662         -0.294884  0.060281
# tempo                0.105812     -0.015485         -0.067688  0.015411
# duration_ms         -0.121596      0.013565          0.042989 -0.042424
# time_signature       0.032491     -0.075186         -0.024616  0.004124
#
#                    valence     tempo  duration_ms  time_signature
# danceability      0.314255 -0.083156    -0.143710        0.101835
# energy            0.240285  0.045193     0.000305        0.066915
# key               0.052988  0.002969     0.031914        0.010861
# loudness          0.231627  0.035191     0.008273        0.056346
# mode             -0.001438 -0.011169    -0.084726       -0.005605
# speechiness       0.198325  0.105812    -0.121596        0.032491
# acousticness     -0.052662 -0.015485     0.013565       -0.075186
# instrumentalness -0.294884 -0.067688     0.042989       -0.024616
# liveness          0.060281  0.015411    -0.042424        0.004124
# valence           1.000000  0.104854     0.034863        0.075062
# tempo             0.104854  1.000000     0.029724       -0.035840
# duration_ms       0.034863  0.029724     1.000000        0.005512
# time_signature    0.075062 -0.035840     0.005512        1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix of Numerical Features')
plt.show()

# %% [markdown]
# ### Interpretation of Heatmap
# #### Strong Positive Correlatoins:
# ##### danceability and valence (.31): moderate positive correlation, indicating that more danceable tracks tend to have a higher valence (happiness or positivity)
#
# ##### energy and loudness (.71): high positive correlation suggests that tracks with higher energy levels tend to also be louder.
#
# ##### energy and valence (.24): moderate positive correlation suggests that tracks with higher energy levels are also more likely to be more positive or happier.
#
# ##### Liveness and energy (.23): moderate positive correlations suggests that tracks that are more lively have higher energy levels.
#
# #### Strong Negative Correlations:
# ##### acousticness and energy (-.48): A strong negative correlation suggests that tracks with higher acousticness tend to have lower energy levels.
#
# ##### instrumentalness and valence (-.29): moderate negative correlation indicates that tracks with higher instrumentalness (less vocals) are often less positive or happier.
#
# ##### danceability and energy (-.21): mild negative correlation indicates that ss one increases, the other tends to decrease, but the relationship is not very strong
#
# #### Unexpected Findings:
# ##### Tempo does not have any strong correlations

# %% [markdown]
# #
# ### Scatter plot for danceability vs. valence

# %%
sample_df = merged_df.sample(n=3000, random_state=1)  # Random sample 3000 points

plt.figure(figsize=(10, 6))
sns.regplot(x='danceability', y='valence', data=sample_df, scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title('Sample Scatter Plot of Danceability vs Valence')
plt.xlabel('Danceability')
plt.ylabel('Valence')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Interpretations
# ##### - there is a tendency for tracks that are more danceable to have a higher valence, suggesting they are generally more positive or happier. However, this relationship is not very strong
# ##### - tracks that are more danceable are often perceived as more positive or happier. This could be relevant in understanding which music genres or styles contribute to higher danceability and positivity-- investigate the genres of the plots that go against this perception
# ##### - Further Analysis: Investigate if specific genres show a stronger or different relationship between danceability and valence

# %% [markdown]
# #
# ### Scatter Plot for Energy vs. Loudness

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=merged_df, x='energy', y='loudness', alpha=0.5)
plt.title('Energy vs Loudness')
plt.xlabel('Energy')
plt.ylabel('Loudness')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Interpretations
# ##### - tracks with higher energy are typically louder
# ##### - could be relevant for genres like electronic dance music or rock, etc., where energetic tracks are often loud (practical implication)
# ##### - Further Exploration: Investigate if certain genres or styles of music show a stronger or different relationship between energy and loudness

# %% [markdown]
# #
# ### Scatter Plot for Energy vs. Valence

# %%
sample_df = merged_df.sample(n=3000, random_state=1)  # Random sample 3000 points


plt.figure(figsize=(10, 6))
sns.regplot(x='energy', y='valence', data=sample_df, scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title('Energy vs Valence')
plt.xlabel('Energy')
plt.ylabel('Valence')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Interpretation
# ##### - The relationship between "mood and genre" might reflect the general trend in music where higher energy tracks tend to be more upbeat or positive. However, given the moderate correlation, there are many energetic tracks that aren't particularly positive and vice versa.
# ##### - Further exploration: Examine if specific genres of music show stronger relationships between energy and valence.

# %% [markdown]
# #
# ### Scatter Plot for Liveness vs. Energy

# %%
plt.figure(figsize=(10, 6))
sns.regplot(x='liveness', y='energy', data=sample_df, scatter_kws={'alpha':0.5}, line_kws={'color':'red'})
plt.title('Liveness vs Energy')
plt.xlabel('Liveness')
plt.ylabel('Energy')
plt.grid(True)
plt.show()

# %% [markdown]
# ### Interpretations
# ##### - While there is a general tendency for higher liveness to be associated with higher energy, there are still many exceptions.
# ##### - there are more tracks with lower liveness, and a few tracks with very high liveness.
# ##### - The correlation, while positive, is not very strong, indicating that liveness is just one of several factors that influence energy.

# %% [markdown]
# #
# #
# ### Distribution Plot for Acousticness

# %%
plt.figure(figsize=(10, 6))
sns.histplot(merged_df['acousticness'], bins=30, kde=True)
plt.title('Distribution of Acousticness')
plt.xlabel('Acousticness')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Interpretation
# ##### - Most Tracks Have Low Acousticness values
# ##### - There are some tracks with higher acousticness, but they are less frequent.
# ##### - Consider investigating why some tracks have extremely high acousticness? Are these tracks of a specific genre or type that typically has more acoustic quality?

# %% [markdown]
# #
# #
# ### Box Plot for Energy by Genre

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(data=merged_df, x='genre', y='energy')
plt.title('Energy by Genre')
plt.xlabel('Genre')
plt.ylabel('Energy')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Interpretations
# ##### - The line inside each box represents the median energy level for that genre. This provides an indication of the typical energy level within each genre
# ##### - For genres that have significantly higher or lower energy levels, it might be worth exploring what characteristics contribute to these differences.
# ##### - For additional analysis:
# ##### - Analyze trends in energy levels across different genres using line chart.
# ##### - Investigate individual genres with extreme values to understand what might be causing these deviations (specific artists?)

# %% [markdown]
# #
# ### Average energy levels by genre using line chart

# %%
energy_by_genre = merged_df.groupby('genre')['energy'].mean().reset_index()
energy_by_genre = energy_by_genre.sort_values(by='energy', ascending=False)
plt.figure(figsize=(10, 6))
sns.lineplot(data=energy_by_genre, x='genre', y='energy', marker='o')
plt.title('Average Energy Levels by Genre')
plt.xlabel('Genre')
plt.ylabel('Average Energy Level')
plt.xticks(rotation=45) 
plt.grid(True)
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Average Energy Levels by Genre BarPlot

# %%
genre_energy_avg = merged_df.groupby('genre')['energy'].mean().reset_index()

plt.figure(figsize=(9, 6))
sns.barplot(data=genre_energy_avg, x='genre', y='energy', palette='viridis')

plt.title('Average Energy Levels by Genre')
plt.xlabel('Genre')
plt.ylabel('Average Energy Level')
plt.xticks(rotation=45)  

plt.tight_layout()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(merged_df['tempo'], bins=30, kde=True, color='blue')
plt.title('Distribution of Tempo')
plt.xlabel('Tempo (BPM)')
plt.ylabel('Frequency')
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ### Interpretations
# ##### - Fairly symmetric with a couple peaks (120, 140, 160)
# ##### - Most songs have a tempo around 140
# ##### - further investigate the genres related to these tempos

# %% [markdown]
# #
# ### Average Tempo by Genre BarPlot

# %%
genre_tempo_avg = merged_df.groupby('genre')['tempo'].mean().reset_index()

plt.figure(figsize=(9, 6))
sns.barplot(data=genre_tempo_avg, x='genre', y='tempo', palette='viridis')
plt.title('Average Tempo by Genre')
plt.xlabel('Genre')
plt.ylabel('Average Tempo (BPM)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #
# ### QUESTIONS FOR ANALYSIS BASED ON DATA EXPLORATION ABOVE
# #
# #### 1. How does tempo vary across different genres, and are there notable patterns?
# ##### - Investigating the distribution of tempo across genres can highlight genre-specific tempo trends and patterns--are certain genres associated with faster or slower tempos and how might this influence the overall genre characteristics.
# #
# #### 2. What are the characteristics of tracks with extreme energy and how do they compare to the overall distribution?
# ##### - energy vs genre: Investigating individual genres with extreme values to understand what might be causing these deviations (specific artists, etc.?)
# #
#
# #
# #### 4.

# %% [markdown]
# #### 3. How do danceability and valence interact across different genres?
# ##### - This question examines whether the relationship between danceability and valence varies across genres
# ##### - Further Analysis from prior graph: Investigate if specific genres show a stronger or different relationship between danceability and valence

# %%
genre_tempo_avg = merged_df.groupby('genre')['danceability'].mean().reset_index()

plt.figure(figsize=(9, 6))
sns.barplot(data=genre_tempo_avg, x='genre', y='danceability', hue='genre', palette='viridis')
plt.title('Average danceability by Genre')
plt.xlabel('Genre')
plt.ylabel('Average danceability')
plt.xticks(rotation=45)
plt.show()

genre_tempo_avg = merged_df.groupby('genre')['valence'].mean().reset_index()
plt.figure(figsize=(9, 6))
sns.barplot(data=genre_tempo_avg, x='genre', y='valence', hue='genre', palette='viridis')
plt.title('Average valence by Genre')
plt.xlabel('Genre')
plt.ylabel('Average valence')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### - Scatter plot of danceability vs. valence, colored by genre

# %%
plt.figure(figsize=(10, 6))
sns.lmplot(x='danceability', y='valence', data=sample_df, hue='genre')
plt.title('danceability vs valence')
plt.xlabel('danceability')
plt.ylabel('valence')
plt.grid(True)
plt.show()
